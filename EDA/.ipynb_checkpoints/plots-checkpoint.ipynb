# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## packed red cell

# %%
packed_red_cells = pd.read_csv('Q2.csv')
packed_red_cells
# Out:
#       hadm_id                   label  totalamount totalamountuom  \
# 0    20006999  Packed Red Blood Cells        279.0             ml
# 1    20032691  Packed Red Blood Cells        283.0             ml
# 2    20044587  Packed Red Blood Cells        279.0             ml
# 3    20087019  Packed Red Blood Cells        350.0             ml
# 4    20088888  Packed Red Blood Cells        350.0             ml
# ..        ...                     ...          ...            ...
# 241  29919383  Packed Red Blood Cells        375.0             ml
# 242  29923776  Packed Red Blood Cells        375.0             ml
# 243  29924353  Packed Red Blood Cells        350.0             ml
# 244  29949404  Packed Red Blood Cells        350.0             ml
# 245  29964086  Packed Red Blood Cells        281.0             ml
#
#                starttime
# 0    2127-06-19T08:15:00
# 1    2123-03-05T16:34:00
# 2    2113-08-25T20:01:00
# 3    2187-08-15T19:55:00
# 4    2143-05-27T04:59:00
# ...

# %%
packed_red_cells.columns
# Out:
# Index(['hadm_id', 'label', 'totalamount', 'totalamountuom', 'starttime'], dtype='object')

# %%
sns.distplot(packed_red_cells['totalamount'], kde=False)
set(packed_red_cells['totalamount'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# {271.0,
#  273.0,
#  274.0,
#  275.0,
#  276.0,
#  277.0,
#  278.0,
#  279.0,
#  280.0,
#  281.0,
#  282.0,
#  283.0,
#  284.0,
#  285.0,
#  289.0,
#  292.0,
#  304.0,
#  350.0,
#  375.0}

# %%
packed_red_cells = pd.read_csv('Q2.csv')
print(packed_red_cells['totalamount'].describe())
packed_red_cells_count_df = packed_red_cells.groupby('totalamount').count().sort_values('hadm_id')

plt.figure(figsize=(70,7))
sns.barplot(x=packed_red_cells_count_df.index, y=packed_red_cells_count_df.hadm_id)
plt.ylabel('Prescription Category Frequency', fontsize=20)
plt.xlabel('Presciption Category', fontsize=20)
plt.show()
# Out:
# count    246.000000
# mean     336.825203
# std       33.108818
# min      271.000000
# 25%      350.000000
# 50%      350.000000
# 75%      350.000000
# max      375.000000
# Name: totalamount, dtype: float64

# %% [markdown]
# ## Last hemoglobin before blood transfusion male compare to female

# %%
last_Hb = pd.read_csv('Q3.csv')
last_Hb
# Out:
#       hadm_id gender       label  valuenum valueuom            charttime
# 0    20006999      M  Hemoglobin       8.5     g/dL  2127-06-19T02:36:00
# 1    20032691      F  Hemoglobin       8.0     g/dL  2123-03-05T13:10:00
# 2    20044587      M  Hemoglobin       9.5     g/dL  2113-08-25T14:48:00
# 3    20087019      F  Hemoglobin       9.8     g/dL  2187-08-15T16:40:00
# 4    20088888      M  Hemoglobin       8.9     g/dL  2143-05-27T02:34:00
# ..        ...    ...         ...       ...      ...                  ...
# 240  29919383      F  Hemoglobin       8.4     g/dL  2139-11-22T03:30:00
# 241  29923776      M  Hemoglobin      10.4     g/dL  2114-04-17T14:32:00
# 242  29924353      M  Hemoglobin       9.0     g/dL  2172-03-24T01:53:00
# 243  29949404      M  Hemoglobin      10.0     g/dL  2169-02-27T12:31:00
# 244  29964086      M  Hemoglobin      11.7     g/dL  2166-04-01T11:45:00
#
# [245 rows x 6 columns]

# %%
male_last_Hb = last_Hb[last_Hb.gender == 'M']
sns.distplot(male_last_Hb['valuenum'], label='male')

female_last_Hb =last_Hb[last_Hb.gender == 'F']
sns.distplot(female_last_Hb['valuenum'],label='female')

# Plot formatting
plt.legend(prop={'size': 12})
plt.title('Last hemoglobin before blood transfusion')
plt.xlabel('valuenum')
plt.ylabel('Density')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

# %%
ax = sns.boxplot(x="gender", y="valuenum", data=last_Hb)

# %% [markdown]
# ## hemoglobin difference before and after blood transfusion male compare to female

# %%
differece_Hb = pd.read_csv('Q4.csv')
differece_Hb
# Out:
#       hadm_id       label  value_before  value_after  value_diff valueuom  \
# 0    20006999  Hemoglobin           8.5          9.7         1.2     g/dL
# 1    20032691  Hemoglobin           8.0          9.9         1.9     g/dL
# 2    20044587  Hemoglobin           9.5          9.3        -0.2     g/dL
# 3    20087019  Hemoglobin           9.8          9.9         0.1     g/dL
# 4    20088888  Hemoglobin           8.9          8.7        -0.2     g/dL
# ..        ...         ...           ...          ...         ...      ...
# 241  29919383  Hemoglobin           8.4         10.5         2.1     g/dL
# 242  29923776  Hemoglobin          10.4          9.8        -0.6     g/dL
# 243  29924353  Hemoglobin           9.0          9.6         0.6     g/dL
# 244  29949404  Hemoglobin          10.0         10.5         0.5     g/dL
# 245  29964086  Hemoglobin          11.7         10.4        -1.3     g/dL
#
#         charttime_before      charttime_after
# ...

# %%
sns.distplot(differece_Hb['value_diff'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='value_diff', ylabel='Density'>

# %%
sns.boxplot(x=differece_Hb["value_diff"])
# Out:
# <AxesSubplot:xlabel='value_diff'>

# %%
differece_Hb = pd.read_csv('Q5.csv')
differece_Hb
# Out:
#       hadm_id gender       label  value_before  value_after  value_diff  \
# 0    20006999      M  Hemoglobin           8.5          9.7         1.2
# 1    20032691      F  Hemoglobin           8.0          9.9         1.9
# 2    20044587      M  Hemoglobin           9.5          9.3        -0.2
# 3    20087019      F  Hemoglobin           9.8          9.9         0.1
# 4    20088888      M  Hemoglobin           8.9          8.7        -0.2
# ..        ...    ...         ...           ...          ...         ...
# 241  29919383      F  Hemoglobin           8.4         10.5         2.1
# 242  29923776      M  Hemoglobin          10.4          9.8        -0.6
# 243  29924353      M  Hemoglobin           9.0          9.6         0.6
# 244  29949404      M  Hemoglobin          10.0         10.5         0.5
# 245  29964086      M  Hemoglobin          11.7         10.4        -1.3
#
#     valueuom     charttime_before      charttime_after
# ...

# %%
sns.distplot(differece_Hb['value_diff'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='value_diff', ylabel='Density'>

# %%
male_differece_Hb = differece_Hb[differece_Hb.gender == 'M']
sns.distplot(male_differece_Hb['value_diff'], label='male')

female_differece_Hb =differece_Hb[differece_Hb.gender == 'F']
sns.distplot(female_differece_Hb['value_diff'],label='female')

# Plot formatting
plt.legend(prop={'size': 12})
plt.title('hemoglobin difference before and after blood transfusion')
plt.xlabel('valuenum')
plt.ylabel('Density')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

# %%
sns.boxplot(x=differece_Hb["value_diff"])
# Out:
# <AxesSubplot:xlabel='value_diff'>

# %%
ax = sns.boxplot(x="gender", y="value_diff", data=differece_Hb)
